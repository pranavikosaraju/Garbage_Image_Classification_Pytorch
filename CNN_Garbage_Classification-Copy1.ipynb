# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split

import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid

# %%
data_path = r"/Users/pranavi/Downloads/Data Science/Garbage Data/Garbage classification/Garbage classification"

# %%
img_size = 120

# %%
img_transform = transforms.Compose([transforms.Resize((img_size, img_size)),
                                   transforms.RandomHorizontalFlip(),
                                   transforms.ToTensor(),
                                   transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])])

# %%
img_data = ImageFolder(root=data_path, transform=img_transform)

# %%
img_data.class_to_idx
# Out:
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}

# %%
len(img_data)
# Out:
# 2527

# %%
train_data, val_data, test_data = random_split(img_data,[1800,627,100])

# %%
len(train_data)
# Out:
# 1800

# %%
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)

# %%
for images, labels in train_loader:
    print(images.shape, labels.shape)
    break
# Out:
# torch.Size([32, 3, 120, 120]) torch.Size([32])

# %%
def show_img_batch(data):
    for images, labels in data:
        plt.figure(figsize=(20,15))
        plt.imshow(make_grid(images, nrow=16).permute(1,2,0))
        plt.show()
        break

# %%
show_img_batch(train_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3) #120-3+1 =118
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3) #59-3+1 = 57
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3) #28-3+1 = 26
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3)
        self.conv5 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3)
        self.pool = nn.MaxPool2d(kernel_size=2)
        self.relu = nn.ReLU()
        self.fc1 = nn.Linear(256,256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64,6)
        
    def forward(self,x):
        x = self.conv1(x) #118*118*16
        x = self.relu(x)
        x = self.pool(x) #59*59*16
        x = self.conv2(x) #57*57*32
        x = self.relu(x)
        x = self.pool(x) # 28*28*32
        x = self.conv3(x) #26*26*48
        x = self.relu(x)
        x = self.pool(x) #13*13*48
        
        x = self.conv4(x) # 11*11*128
        x = self.relu(x)
        x = self.pool(x) # 5*5*128
        x = self.conv5(x) # 
        x = self.relu(x)
        x = self.pool(x)
        x = x.view(-1, 256)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)
        x = self.relu(x)
        x = self.fc4(x)
        
        return x

# %%
model = CNN()
print(model.parameters)
# Out:
# <bound method Module.parameters of CNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (fc1): Linear(in_features=256, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=64, bias=True)
#   (fc4): Linear(in_features=64, out_features=6, bias=True)
# )>

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
epochs=30

training_loss = []
training_acc = []
testing_loss =[]
testing_acc = []

for epoch in range(epochs):

    train_acc = 0.0
    train_loss = 0.0

    model.train()

    for images, labels in train_loader:
        optimizer.zero_grad()
        output = model(images)
        loss = loss_fn(output, labels)

        loss.backward()
        optimizer.step()

        predictions = torch.argmax(output,1)

        train_acc += (predictions==labels).sum().item()
        train_loss += loss.item()

    training_acc.append(train_acc/len(train_data))
    training_loss.append(train_loss/len(train_loader))

    model.eval()

    test_acc = 0.0
    test_loss = 0.0

    with torch.no_grad():
        for images, labels in val_loader:
            output = model(images)
            loss = loss_fn(output, labels)

            predictions = torch.argmax(output,1)

            test_acc += (predictions==labels).sum().item()
            test_loss += loss.item()

        testing_acc.append(test_acc/len(val_data))
        testing_loss.append(test_loss/len(val_loader))

    print("Epochs:{}, Training Accuracy:{:.2f}, Training Loss:{:.2f}, Testing Accuracy:{:.2f}, Testing Loss:{:.2f}".format(
        epoch+1, train_acc/len(train_data), train_loss/len(train_loader), test_acc/len(val_data), 
            test_loss/len(val_loader)))
# Out:
# Epochs:1, Training Accuracy:0.23, Training Loss:1.72, Testing Accuracy:0.26, Testing Loss:1.67
# Epochs:2, Training Accuracy:0.29, Training Loss:1.64, Testing Accuracy:0.35, Testing Loss:1.60
# Epochs:3, Training Accuracy:0.34, Training Loss:1.59, Testing Accuracy:0.33, Testing Loss:1.57
# Epochs:4, Training Accuracy:0.34, Training Loss:1.51, Testing Accuracy:0.37, Testing Loss:1.47
# Epochs:5, Training Accuracy:0.41, Training Loss:1.43, Testing Accuracy:0.42, Testing Loss:1.44
# Epochs:6, Training Accuracy:0.42, Training Loss:1.40, Testing Accuracy:0.41, Testing Loss:1.43
# Epochs:7, Training Accuracy:0.43, Training Loss:1.37, Testing Accuracy:0.42, Testing Loss:1.47
# Epochs:8, Training Accuracy:0.45, Training Loss:1.34, Testing Accuracy:0.44, Testing Loss:1.34
# Epochs:9, Training Accuracy:0.46, Training Loss:1.33, Testing Accuracy:0.44, Testing Loss:1.37
# Epochs:10, Training Accuracy:0.50, Training Loss:1.27, Testing Accuracy:0.48, Testing Loss:1.30
# Epochs:11, Training Accuracy:0.51, Training Loss:1.25, Testing Accuracy:0.50, Testing Loss:1.27
# Epochs:12, Training Accuracy:0.53, Training Loss:1.22, Testing Accuracy:0.52, Testing Loss:1.24
# Epochs:13, Training Accuracy:0.54, Training Loss:1.17, Testing Accuracy:0.55, Testing Loss:1.19
# Epochs:14, Training Accuracy:0.56, Training Loss:1.12, Testing Accuracy:0.55, Testing Loss:1.21
# Epochs:15, Training Accuracy:0.56, Training Loss:1.15, Testing Accuracy:0.55, Testing Loss:1.22
# Epochs:16, Training Accuracy:0.59, Training Loss:1.09, Testing Accuracy:0.57, Testing Loss:1.14
# Epochs:17, Training Accuracy:0.62, Training Loss:0.99, Testing Accuracy:0.57, Testing Loss:1.19
# Epochs:18, Training Accuracy:0.61, Training Loss:1.00, Testing Accuracy:0.57, Testing Loss:1.13
# Epochs:19, Training Accuracy:0.63, Training Loss:0.99, Testing Accuracy:0.65, Testing Loss:1.02
# Epochs:20, Training Accuracy:0.63, Training Loss:0.95, Testing Accuracy:0.59, Testing Loss:1.16
# Epochs:21, Training Accuracy:0.65, Training Loss:0.90, Testing Accuracy:0.60, Testing Loss:1.04
# Epochs:22, Training Accuracy:0.68, Training Loss:0.88, Testing Accuracy:0.61, Testing Loss:1.10
# Epochs:23, Training Accuracy:0.69, Training Loss:0.84, Testing Accuracy:0.63, Testing Loss:1.00
# Epochs:24, Training Accuracy:0.72, Training Loss:0.77, Testing Accuracy:0.60, Testing Loss:1.10
# Epochs:25, Training Accuracy:0.73, Training Loss:0.70, Testing Accuracy:0.63, Testing Loss:1.07
# Epochs:26, Training Accuracy:0.73, Training Loss:0.70, Testing Accuracy:0.57, Testing Loss:1.28
# Epochs:27, Training Accuracy:0.75, Training Loss:0.68, Testing Accuracy:0.63, Testing Loss:1.08
# Epochs:28, Training Accuracy:0.77, Training Loss:0.60, Testing Accuracy:0.68, Testing Loss:0.97
# Epochs:29, Training Accuracy:0.81, Training Loss:0.53, Testing Accuracy:0.66, Testing Loss:1.01
# Epochs:30, Training Accuracy:0.80, Training Loss:0.53, Testing Accuracy:0.64, Testing Loss:1.11

# %%
plt.title("Accuracy Vs Epochs")
plt.plot(range(epochs), training_acc, label="Training Accuracy")
plt.plot(range(epochs), testing_acc, label="Testing Accuracy")
plt.xlabel("Accuracy")
plt.ylabel("Epochs")
plt.legend()
plt.show()

# %%
plt.title("Loss Vs Epochs")
plt.plot(range(epochs), testing_loss, label="Testing Loss")
plt.plot(range(epochs), training_loss, label="Training Loss")
plt.xlabel("Loss")
plt.ylabel("Epochs")
plt.legend()
plt.show()

# %%
def image_predict(img, model):
    x = img.unsqueeze(0)
    y = model(x)
    
    prediction = torch.argmax(y, dim=1)
    
    return img_data.classes[prediction]

# %%
img, label = test_data[10]
plt.imshow(img.permute(1,2,0))
print("Actual Label:", img_data.classes[label],"Predicted Label:", image_predict(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Actual Label: glass Predicted Label: glass

# %%
img, label = test_data[19]
plt.imshow(img.permute(1,2,0))
print("Actual Label:", img_data.classes[label],"Predicted Label:", image_predict(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Actual Label: paper Predicted Label: paper

# %%
img, label = test_data[74]
plt.imshow(img.permute(1,2,0))
print("Actual Label:", img_data.classes[label],"Predicted Label:", image_predict(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Actual Label: cardboard Predicted Label: cardboard

# %%
img, label = test_data[96]
plt.imshow(img.permute(1,2,0))
print("Actual Label:", img_data.classes[label],"Predicted Label:", image_predict(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Actual Label: plastic Predicted Label: plastic
